# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('car data.csv')

# %%
df.sample(5)
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 43                dzire  2014           5.50           8.06       45780
# 79             fortuner  2012          14.50          30.61       89000
# 17               ertiga  2016           7.75          10.79       43000
# 101  UM Renegade Mojave  2017           1.70           1.82        1400
# 264               amaze  2015           4.00           7.00       40026
#
#     Fuel_Type Seller_Type Transmission  Owner
# 43     Diesel      Dealer       Manual      0
# 79     Diesel      Dealer    Automatic      0
# 17     Diesel      Dealer       Manual      0
# 101    Petrol  Individual       Manual      0
# 264    Petrol      Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
print(df['Seller_Type'].unique())
print(df['Transmission'].unique())
print(df['Owner'].unique())
print(df['Fuel_Type'].unique())
# Out:
# ['Dealer' 'Individual']
# ['Manual' 'Automatic']
# [0 1 3]
# ['Petrol' 'Diesel' 'CNG']

# %%
#cheching missing values

df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df1 = df.copy()

# %%
df1 = df.drop('Car_Name',axis = 1)

# %%
df1.sample(3)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 133  2016           0.72           0.95         500    Petrol  Individual
# 234  2015           5.50           5.70        4492    Petrol      Dealer
# 266  2014           3.65           7.00       35000    Petrol      Dealer
#
#     Transmission  Owner
# 133       Manual      0
# 234       Manual      0
# 266       Manual      0

# %%
df1['Current_Year'] = 2022

# %%
df1.sample(3)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 73   2011           2.65           5.71       43000    Petrol      Dealer
# 285  2016           7.40           8.50       15059    Petrol      Dealer
# 276  2015           8.65          13.60       24800    Petrol      Dealer
#
#     Transmission  Owner  Current_Year
# 73        Manual      0          2022
# 285    Automatic      0          2022
# 276       Manual      0          2022

# %%
df1['Age_of_Car'] = df1["Current_Year"] - df1['Year']

# %%
df1.sample(3)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 263  2016           6.60           7.70       16002    Petrol      Dealer
# 47   2006           1.05           4.15       65000    Petrol      Dealer
# 39   2003           2.25           7.98       62000    Petrol      Dealer
#
#     Transmission  Owner  Current_Year  Age_of_Car
# 263       Manual      0          2022           6
# 47        Manual      0          2022          16
# 39        Manual      0          2022          19

# %%
df1.drop('Year', axis = 1, inplace=True)

# %%
df1.sample(3)
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 57            4.75          18.54       50000    Petrol      Dealer
# 75            3.95           6.80       36000    Petrol      Dealer
# 145           0.60           0.81       19000    Petrol  Individual
#
#     Transmission  Owner  Current_Year  Age_of_Car
# 57        Manual      0          2022          12
# 75        Manual      0          2022           7
# 145       Manual      0          2022          10

# %%
df1.drop('Current_Year', axis = 1, inplace=True)

# %%
df1.sample(3)
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 170            0.4           0.83        5500    Petrol  Individual
# 270            4.1          10.00       69341    Petrol      Dealer
# 173            0.4           0.51        1300    Petrol  Individual
#
#     Transmission  Owner  Age_of_Car
# 170       Manual      0          10
# 270       Manual      0          11
# 173    Automatic      0           5

# %%
df.Car_Name.nunique()
# Out:
# 98

# %%
df1 = pd.get_dummies(df1,drop_first = True)

# %%
df1.sample(3)
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age_of_Car  \
# 274           5.30           6.80       16500      0           8
# 20            2.85           3.95       25000      0           6
# 129           0.78           0.84        5000      0           5
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 274                 0                 1                       0
# 20                  0                 1                       0
# 129                 0                 1                       1
#
#      Transmission_Manual
# 274                    1
# 20                     1
# 129                    1

# %%
df1.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# Age_of_Car                  -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         Age_of_Car  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price            -0.236141          0.552339         -0.540571
# Present_Price             0.047584          0.473306         -0.465244
# Kms_Driven                0.524342          0.172515         -0.172874
# Owner                     0.182104         -0.053469          0.055687
# Age_of_Car                1.000000         -0.064315          0.059959
# Fuel_Type_Diesel         -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol          0.059959         -0.979648          1.000000
# Seller_Type_Individual    0.039896         -0.350467          0.358321
# Transmission_Manual      -0.000394         -0.098643          0.091013
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.550724            -0.367128
# Present_Price                        -0.512030            -0.348715
# Kms_Driven                           -0.101419            -0.162510
# Owner                                 0.124269            -0.050316
# Age_of_Car                            0.039896            -0.000394
# Fuel_Type_Diesel                     -0.350467            -0.098643
# Fuel_Type_Petrol                      0.358321             0.091013
# Seller_Type_Individual                1.000000             0.063240
# Transmission_Manual                   0.063240             1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df1.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df1)
sns

# %%
X = df1.drop('Selling_Price', axis = 1)
y = df1.Selling_Price

# %%
X.sample(3)
# Out:
#      Present_Price  Kms_Driven  Owner  Age_of_Car  Fuel_Type_Diesel  \
# 146          0.787       15000      0           8                 0
# 20           3.950       25000      0           6                 0
# 125          1.750       40000      0          13                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 146                 1                       1                    1
# 20                  1                       0                    1
# 125                 1                       1                    1

# %%
y.sample(3)
# Out:
# 269    6.70
# 214    5.25
# 218    6.45
# Name: Selling_Price, dtype: float64
